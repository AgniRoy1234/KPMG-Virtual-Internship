# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import warnings
warnings.filterwarnings('ignore')

# %%
matplotlib.rcParams["figure.figsize"]=(20,10)
# %matplotlib inline

# %%
address='/content/drive/MyDrive/ColabNotebooks/KPMG Virtual Internship/data quality/kpmgdata.xlsx'

# %%
c=pd.read_excel(address,sheet_name='CustomerDemographic',header=1)

# %%
t=pd.read_excel(address,sheet_name='Transactions',header=1)

# %%
c.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
c.drop('default',axis=1,inplace=True)

# %% [markdown]
# #checking if there is any customer id in the transactions table that doesnot have a customer information

# %%
j1=t.merge(c,how='left',on='customer_id')

# %%
c1=t.customer_id 
c2=c.customer_id

# %%
c1=sorted(c1)
c2=sorted(c2)

# %%
len(c1)
# Out:
# 20000

# %%
len(c2)
# Out:
# 4000

# %%
c1[-4]
# Out:
# 3500

# %%
for i in c1:
  if i not in c2:
    print(i)
# Out:
# 5034
# 5034
# 5034

# %% [markdown]
# hence we see that there is a customer id 5034 in the transactions table about which we get no info in the customerdemographics table

# %%
t[t.customer_id==5034]
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 8707             8708           0         5034       2017-10-07           0.0
# 16700           16701           0         5034       2017-01-27           0.0
# 17468           17469           0         5034       2017-01-03           0.0
#
#       order_status           brand product_line product_class product_size  \
# 8707      Approved           Solex         Road        medium       medium
# 16700     Approved  Norco Bicycles     Standard        medium       medium
# 17468     Approved      OHM Cycles         Road        medium       medium
#
#        list_price  standard_cost product_first_sold_date
# 8707       416.98     312.735016              2015-08-02
# 16700      360.40     270.299988              1997-08-25
# 17468      742.54     667.400024              1992-10-02

# %%
c[c.customer_id==5034]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, last_name, gender, past_3_years_bike_related_purchases, DOB, job_title, job_industry_category, wealth_segment, deceased_indicator, owns_car, tenure]
# Index: []

# %%
j1[j1.customer_id==5034]
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 8707             8708           0         5034       2017-10-07           0.0
# 16700           16701           0         5034       2017-01-27           0.0
# 17468           17469           0         5034       2017-01-03           0.0
#
#       order_status           brand product_line product_class product_size  \
# 8707      Approved           Solex         Road        medium       medium
# 16700     Approved  Norco Bicycles     Standard        medium       medium
# 17468     Approved      OHM Cycles         Road        medium       medium
#
#        ...  last_name  gender past_3_years_bike_related_purchases DOB  \
# 8707   ...        NaN     NaN                                 NaN NaT
# 16700  ...        NaN     NaN                                 NaN NaT
# 17468  ...        NaN     NaN                                 NaN NaT
#
# ...

# %% [markdown]
# #doing the same for address

# %%
a=pd.read_excel(address,sheet_name='CustomerAddress',header=1)

# %%
c3=sorted(a.customer_id )

# %%
for i in c1:
  if i not in c3:
    print(i)
# Out:
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 10
# 10
# 10
# 10
# 10
# 10
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 5034
# 5034
# 5034

# %%
for i in c2:
  if i not in c3:
    print(i)
# Out:
# 3
# 10
# 22
# 23

# %%
a[a.customer_id==23]
# Out:
# Empty DataFrame
# Columns: [customer_id, address, postcode, state, country, property_valuation]
# Index: []
