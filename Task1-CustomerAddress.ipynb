# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import warnings
warnings.filterwarnings('ignore')
matplotlib.rcParams["figure.figsize"]=(20,10)
# %matplotlib inline

# %%
address='/content/drive/MyDrive/ColabNotebooks/KPMG Virtual Internship/data quality/kpmgdata.xlsx'

# %%
a=pd.read_excel(address,sheet_name='CustomerAddress',header=1)

# %% [markdown]
# #Elementary Analysis

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB

# %%
a.isna().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %% [markdown]
# apparently no missing values are present

# %% [markdown]
# #checking unique values

# %%
a.columns
# Out:
# Index(['customer_id', 'address', 'postcode', 'state', 'country',
#        'property_valuation'],
#       dtype='object')

# %%
a.shape
# Out:
# (3999, 6)

# %%
a.customer_id.nunique()
# Out:
# 3999

# %%
for i in a.columns[[2,3,4]]:
  print(f'for column {i} the unique values are')
  print(a[i].unique())
  print('*'*100)
# Out:
# for column postcode the unique values are
# [2016 2153 4211 2448 3216 2210 2650 2023 3044 4557 3799 2760 2428 3331
#  3058 2135 2233 2444 4413 4740 3218 4868 4116 2519 2756 2170 4005 4127
#  2535 4726 4805 2212 2207 3350 3931 4018 4670 2480 3212 2322 3198 2047
#  4503 2145 4350 2142 2029 2127 4280 2166 2046 2026 2765 2749 2745 3752
#  2217 2230 3046 3183 2070 2213 4208 2774 4133 4213 4170 2073 3561 2330
#  3977 2204 2086 2226 2075 2038 2069 2100 3133 3070 2777 2125 2766 2209
#  2160 2065 2150 2168 4171 2155 2517 2096 2750 2093 3204 4300 3844 4226
#  3192 2485 2097 4817 2516 3074 4508 4405 2452 2205 4132 4744 2158 3201
#  4178 2112 2033 4401 3186 4017 2315 2285 2219 4509 2759 2747 2227 2025
#  3191 3025 2263 2154 2119 3016 4113 2032 4352 3020 2116 3057 2099 3749
#  2148 3145 2021 2333 2783 2280 4120 3638 2074 2880 2430 4560 2088 2220
#  3031 2250 2261 3196 4680 3143 2063 3021 2138 4811 2085 3084 3170 2066
#  4078 2222 3152 2159 4655 4220 4012 2015 2776 3011 2761 2502 2110 2566
# ...

# %% [markdown]
# we see that for the column state the unique values have been repeated. New South Wales=NSW and Victoria=VIC

# %%
a.address
# Out:
# 0              060 Morning Avenue
# 1             6 Meadow Vale Court
# 2              0 Holy Cross Court
# 3             17979 Del Mar Point
# 4                9 Oakridge Court
#                   ...
# 3994              1482 Hauk Trail
# 3995    57042 Village Green Point
# 3996       87 Crescent Oaks Alley
# 3997             8194 Lien Street
# 3998              320 Acker Drive
# Name: address, Length: 3999, dtype: object

# %% [markdown]
# #checking state and postcode

# %%
for i in a.state.unique():
  a1=a[a.state==i]
  print(f'For State {i}')
  print(sorted(a1.postcode.unique()))
  print('*'*50)
# Out:
# For State New South Wales
# [2016, 2023, 2026, 2029, 2033, 2038, 2046, 2047, 2065, 2069, 2070, 2073, 2075, 2086, 2093, 2096, 2097, 2100, 2112, 2125, 2127, 2135, 2142, 2145, 2150, 2153, 2155, 2158, 2160, 2166, 2168, 2170, 2204, 2205, 2207, 2209, 2210, 2212, 2213, 2217, 2219, 2226, 2230, 2233, 2285, 2315, 2322, 2330, 2428, 2444, 2448, 2452, 2480, 2485, 2516, 2517, 2519, 2535, 2650, 2745, 2749, 2750, 2756, 2760, 2765, 2766, 2774, 2777]
# **************************************************
# For State QLD
# ...

# %% [markdown]
# we found no contradiction here

# %%
a.property_valuation.unique()
# Out:
# array([10,  9,  4, 12,  8,  6,  7,  3,  5, 11,  1,  2])
